# %% [markdown]
# ## Merging Multiple Datasets Together

# %% [markdown]
# ### Purpose of This Jupyter Notebook
#
# This notebook shows how to merge multiple datasets together in python to create one large dataset that can be used for analysis.

# %% [markdown]
# ## Context
#
# There's historical sales data for 45 stores located in different regions - each store contains a number of departments. The company also runs several promotional markdown events throughout the year. These markdowns precede prominent holidays, the four largest of which are the Super Bowl, Labor Day, Thanksgiving, and Christmas. The weeks including these holidays are weighted five times higher in the evaluation than non-holiday weeks.
#
# There are 3 csv files: Stores, Features and Sales

# %%
import pandas as pd
pd.options.display.max_columns = None

# %% [markdown]
# #### Loading and inspecting the features csv file.

# %%
features = pd.read_csv('features_data.csv')
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
features.dtypes
# Out:
# Store             int64
# Date             object
# Temperature     float64
# Fuel_Price      float64
# MarkDown1       float64
# MarkDown2       float64
# MarkDown3       float64
# MarkDown4       float64
# MarkDown5       float64
# CPI             float64
# Unemployment    float64
# IsHoliday          bool
# dtype: object

# %%
# Converting the date field to a datatime.
features['Date'] = pd.to_datetime(features['Date'])
features.dtypes
# Out:
# Store                    int64
# Date            datetime64[ns]
# Temperature            float64
# Fuel_Price             float64
# MarkDown1              float64
# MarkDown2              float64
# MarkDown3              float64
# MarkDown4              float64
# MarkDown5              float64
# CPI                    float64
# Unemployment           float64
# IsHoliday                 bool
# dtype: object

# %%
# Even though there's missing data in the features table, we don't want to drop any of the rows since we're going to be merging
# datasets together.
features.describe(include='all')
# Out:
# <ipython-input-6-fd7c7d0d9ac0>:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   features.describe(include='all')
#               Store                 Date  Temperature   Fuel_Price  \
# count   8190.000000                 8190  8190.000000  8190.000000
# unique          NaN                  182          NaN          NaN
# top             NaN  2011-07-15 00:00:00          NaN          NaN
# freq            NaN                   45          NaN          NaN
# first           NaN  2010-01-10 00:00:00          NaN          NaN
# last            NaN  2013-12-07 00:00:00          NaN          NaN
# mean      23.000000                  NaN    59.356198     3.405992
# std       12.987966                  NaN    18.678607     0.431337
# min        1.000000                  NaN    -7.290000     2.472000
# 25%       12.000000                  NaN    45.902500     3.041000
# 50%       23.000000                  NaN    60.710000     3.513000
# 75%       34.000000                  NaN    73.880000     3.743000
# max       45.000000                  NaN   101.950000     4.468000
#
#             MarkDown1      MarkDown2      MarkDown3     MarkDown4  \
# count     4032.000000    2921.000000    3613.000000   3464.000000
# unique            NaN            NaN            NaN           NaN
# top               NaN            NaN            NaN           NaN
# freq              NaN            NaN            NaN           NaN
# first             NaN            NaN            NaN           NaN
# last              NaN            NaN            NaN           NaN
# mean      7032.371786    3384.176594    1760.100180   3292.935886
# std       9262.747448    8793.583016   11276.462208   6792.329861
# min      -2781.450000    -265.760000    -179.260000      0.220000
# 25%       1577.532500      68.880000       6.600000    304.687500
# 50%       4743.580000     364.570000      36.260000   1176.425000
# 75%       8923.310000    2153.350000     163.150000   3310.007500
# max     103184.980000  104519.540000  149483.310000  67474.850000
#
#             MarkDown5          CPI  Unemployment IsHoliday
# count     4050.000000  7605.000000   7605.000000      8190
# unique            NaN          NaN           NaN         2
# top               NaN          NaN           NaN     False
# freq              NaN          NaN           NaN      7605
# first             NaN          NaN           NaN       NaN
# last              NaN          NaN           NaN       NaN
# mean      4132.216422   172.460809      7.826821       NaN
# std      13086.690278    39.738346      1.877259       NaN
# min       -185.170000   126.064000      3.684000       NaN
# 25%       1440.827500   132.364839      6.634000       NaN
# 50%       2727.135000   182.764003      7.806000       NaN
# 75%       4832.555000   213.932412      8.567000       NaN
# max     771448.100000   228.976456     14.313000       NaN

# %% [markdown]
# #### Loading and inspecting the sales csv file.

# %%
sales = pd.read_csv('sales_data.csv')
sales.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
sales.dtypes
# Out:
# Store             int64
# Dept              int64
# Date             object
# Weekly_Sales    float64
# IsHoliday          bool
# dtype: object

# %%
# Converting the date field to a datatime.
sales['Date'] = pd.to_datetime(sales['Date'])
sales.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# IsHoliday                 bool
# dtype: object

# %%
# No missing data in the date field.
sales.describe(include='all')
# Out:
# <ipython-input-10-36be9884006d>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   sales.describe(include='all')
#                 Store           Dept                 Date   Weekly_Sales  \
# count   421570.000000  421570.000000               421570  421570.000000
# unique            NaN            NaN                  143            NaN
# top               NaN            NaN  2011-12-23 00:00:00            NaN
# freq              NaN            NaN                 3027            NaN
# first             NaN            NaN  2010-01-10 00:00:00            NaN
# last              NaN            NaN  2012-12-10 00:00:00            NaN
# mean        22.200546      44.260317                  NaN   15981.258123
# std         12.785297      30.492054                  NaN   22711.183519
# min          1.000000       1.000000                  NaN   -4988.940000
# 25%         11.000000      18.000000                  NaN    2079.650000
# 50%         22.000000      37.000000                  NaN    7612.030000
# 75%         33.000000      74.000000                  NaN   20205.852500
# max         45.000000      99.000000                  NaN  693099.360000
#
#        IsHoliday
# count     421570
# unique         2
# top        False
# freq      391909
# first        NaN
# last         NaN
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %% [markdown]
# #### Loading and inspecting the stores csv file.

# %%
stores = pd.read_csv('stores_data.csv')
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
# No missing data in the stores table.
stores.describe(include='all')
# Out:
#             Store Type           Size
# count   45.000000   45      45.000000
# unique        NaN    3            NaN
# top           NaN    A            NaN
# freq          NaN   22            NaN
# mean    23.000000  NaN  130287.600000
# std     13.133926  NaN   63825.271991
# min      1.000000  NaN   34875.000000
# 25%     12.000000  NaN   70713.000000
# 50%     23.000000  NaN  126512.000000
# 75%     34.000000  NaN  202307.000000
# max     45.000000  NaN  219622.000000

# %% [markdown]
# ### Merging all three datasetes together.

# %%
# Merging features and sales together based off the Store, Date and IsHoliday field since those are the fields they have in common.
df=pd.merge(features,sales, on=['Store','Date', 'IsHoliday'], how='left')

# Merging the new dataset we created with the store dataset based off the store field since that's the field they have in common.
df=pd.merge(df,stores, on=['Store'], how='left')

# %%
df.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-05-02        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-05-02        42.31       2.572        NaN        NaN        NaN
# 2      1 2010-05-02        42.31       2.572        NaN        NaN        NaN
# 3      1 2010-05-02        42.31       2.572        NaN        NaN        NaN
# 4      1 2010-05-02        42.31       2.572        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# 0        NaN        NaN  211.096358         8.106      False   1.0
# 1        NaN        NaN  211.096358         8.106      False   2.0
# 2        NaN        NaN  211.096358         8.106      False   3.0
# 3        NaN        NaN  211.096358         8.106      False   4.0
# 4        NaN        NaN  211.096358         8.106      False   5.0
#
#    Weekly_Sales Type    Size
# 0      24924.50    A  151315
# 1      50605.27    A  151315
# 2      13740.12    A  151315
# 3      39954.04    A  151315
# 4      32229.38    A  151315

# %%
df.describe(include='all')
# Out:
# <ipython-input-15-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#                 Store                 Date    Temperature     Fuel_Price  \
# count   423325.000000               423325  423325.000000  423325.000000
# unique            NaN                  182            NaN            NaN
# top               NaN  2011-12-23 00:00:00            NaN            NaN
# freq              NaN                 3027            NaN            NaN
# first             NaN  2010-01-10 00:00:00            NaN            NaN
# last              NaN  2013-12-07 00:00:00            NaN            NaN
# mean        22.203860                  NaN      60.067140       3.361933
# std         12.786244                  NaN      18.452599       0.458038
# min          1.000000                  NaN      -7.290000       2.472000
# 25%         11.000000                  NaN      46.670000       2.935000
# 50%         22.000000                  NaN      62.070000       3.452000
# 75%         33.000000                  NaN      74.260000       3.738000
# max         45.000000                  NaN     101.950000       4.468000
#
#             MarkDown1      MarkDown2      MarkDown3      MarkDown4  \
# count   152433.000000  112532.000000  138658.000000  136466.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# first             NaN            NaN            NaN            NaN
# last              NaN            NaN            NaN            NaN
# mean      7246.604247    3337.597289    1449.098932    3382.019834
# std       8319.906707    9461.265420    9674.705234    6306.728468
# min      -2781.450000    -265.760000    -179.260000       0.220000
# 25%       2230.800000      42.000000       5.140000     500.910000
# 50%       5336.520000     194.670000      24.830000    1465.540000
# 75%       9210.900000    1943.200000     104.500000    3592.000000
# max     103184.980000  104519.540000  149483.310000   67474.850000
#
#             MarkDown5            CPI   Unemployment IsHoliday           Dept  \
# count   153187.000000  422740.000000  422740.000000    423325  421570.000000
# unique            NaN            NaN            NaN         2            NaN
# top               NaN            NaN            NaN     False            NaN
# freq              NaN            NaN            NaN    393529            NaN
# first             NaN            NaN            NaN       NaN            NaN
# last              NaN            NaN            NaN       NaN            NaN
# mean      4618.743783     171.218863       7.957296       NaN      44.260317
# std       6258.233496      39.167088       1.863433       NaN      30.492054
# min       -185.170000     126.064000       3.684000       NaN       1.000000
# 25%       1863.720000     132.022667       6.891000       NaN      18.000000
# 50%       3340.020000     182.350989       7.866000       NaN      37.000000
# 75%       5535.130000     212.512605       8.567000       NaN      74.000000
# max     771448.100000     228.976456      14.313000       NaN      99.000000
#
#          Weekly_Sales    Type           Size
# count   421570.000000  423325  423325.000000
# unique            NaN       3            NaN
# top               NaN       A            NaN
# freq              NaN  216336            NaN
# first             NaN     NaN            NaN
# last              NaN     NaN            NaN
# mean     15981.258123     NaN  136701.215794
# std      22711.183519     NaN   60990.977801
# min      -4988.940000     NaN   34875.000000
# 25%       2079.650000     NaN   93638.000000
# 50%       7612.030000     NaN  140167.000000
# 75%      20205.852500     NaN  202505.000000
# max     693099.360000     NaN  219622.000000

# %%
# Dropping rows with missing values in them.
# We're using this option instead of filling in missing values as there are too many missing values in the dataset.
df2 = df.dropna()

# %%
# Here we can see that there are no missing values in the dataset.

# Data types of the fields.
tab_info = pd.DataFrame(df2.dtypes).T.rename(index={0:'column Type'}) 

# Number of missing values.
tab_info = tab_info.append(pd.DataFrame(df2.isnull().sum()).T.rename(index={0:'null values (nb)'}))

# Percent of missing values.
tab_info = tab_info.append(pd.DataFrame(df2.isnull().sum()/df.shape[0]*100).T.
                                       rename(index={0: 'null values (%)'}))
tab_info
# Out:
#                   Store            Date Temperature Fuel_Price MarkDown1  \
# column Type       int64  datetime64[ns]     float64    float64   float64
# null values (nb)      0               0           0          0         0
# null values (%)       0               0           0          0         0
#
#                  MarkDown2 MarkDown3 MarkDown4 MarkDown5      CPI  \
# column Type        float64   float64   float64   float64  float64
# null values (nb)         0         0         0         0        0
# null values (%)          0         0         0         0        0
#
#                  Unemployment IsHoliday     Dept Weekly_Sales    Type   Size
# column Type           float64      bool  float64      float64  object  int64
# null values (nb)            0         0        0            0       0      0
# null values (%)             0         0        0            0       0      0
